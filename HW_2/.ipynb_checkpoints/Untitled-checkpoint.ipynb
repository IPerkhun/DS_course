# %%
import pandas as pd
import numpy as np

# %%
names =['DATE','TIME','CO_GT','PT08_S1_CO','NMHC_GT','C6H6_GT','PT08_S2_NMHC',
     'NOX_GT','PT08_S3_NOX','NO2_GT','PT08_S4_NO2','PT08_S5_O3','T','RH','AH', '1', '1']

df = pd.read_csv('../res/AirQualityUCI/AirQualityUCI.csv', sep=';', names=names)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9472 entries, 0 to 9471
# Data columns (total 17 columns):
# DATE            9358 non-null object
# TIME            9358 non-null object
# CO_GT           9358 non-null object
# PT08_S1_CO      9358 non-null object
# NMHC_GT         9358 non-null object
# C6H6_GT         9358 non-null object
# PT08_S2_NMHC    9358 non-null object
# NOX_GT          9358 non-null object
# PT08_S3_NOX     9358 non-null object
# NO2_GT          9358 non-null object
# PT08_S4_NO2     9358 non-null object
# PT08_S5_O3      9358 non-null object
# T               9358 non-null object
# RH              9358 non-null object
# AH              9358 non-null object
# 1               0 non-null float64
# 1.1             0 non-null float64
# dtypes: float64(2), object(15)
# memory usage: 1.2+ MB
# /Users/perhunivan/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py:678: UserWarning: Duplicate names specified. This will raise an error in the future.
# ...

# %%
df
# Out:
#             DATE      TIME   CO_GT   PT08_S1_CO   NMHC_GT   C6H6_GT  \
# 0           Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)
# 1     10/03/2004  18.00.00     2,6         1360       150      11,9
# 2     10/03/2004  19.00.00       2         1292       112       9,4
# 3     10/03/2004  20.00.00     2,2         1402        88       9,0
# 4     10/03/2004  21.00.00     2,2         1376        80       9,2
# 5     10/03/2004  22.00.00     1,6         1272        51       6,5
# 6     10/03/2004  23.00.00     1,2         1197        38       4,7
# 7     11/03/2004  00.00.00     1,2         1185        31       3,6
# 8     11/03/2004  01.00.00       1         1136        31       3,3
# 9     11/03/2004  02.00.00     0,9         1094        24       2,3
# 10    11/03/2004  03.00.00     0,6         1010        19       1,7
# 11    11/03/2004  04.00.00    -200         1011        14       1,3
# 12    11/03/2004  05.00.00     0,7         1066         8       1,1
# ...
